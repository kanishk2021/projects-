# %%
import pandas as pd
import numpy as np
impo

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#there are no null values

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#now we will see correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
col=df.columns
col
for i in col[1:]:
    print(i)
    plt.figure()
    sns.scatterplot(data=df,x='W',y=i)
    plt.show()
# Out:
# R
# AB
# H
# 2B
# 3B
# HR
# BB
# SO
# SB
# RA
# ER
# ERA
# CG
# SHO
# SV
# E

# %%
#we can see some pattern that means they are correlated somewhere

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()["W"].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %%
#we can see from SV to H columns are positively correalted and rest is negatively correlated.SV is highly correalted and ERA is very less correalted

# %%
df.plot(kind="density",subplots=True,layout=(4,5),sharex=False,fontsize=1,figsize=(18,12))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#we have seen distribution through graph we have skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
x=df.drop("W",axis=1)
y=df["W"]

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

df_new=power_transform(df)
df=pd.DataFrame(df_new, columns=df.columns)
# Out:
# C:\Users\91708\AppData\Roaming\Python\Python38\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
x.plot(kind="density",subplots=True,layout=(4,5),sharex=False,fontsize=1,figsize=(18,12))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# we have reomve skewness

# %%
#plotting box plot for my dataframe to check and remove outliers
plt.figure(figsize=(50,45),facecolor="white")
plotnumber = 1

for column in x:
    
    if(x[column].dtype == np.float64 or x[column].dtype == np.int64):
        if plotnumber<=34:
            ax = plt.subplot(7,5,plotnumber)
            sns.boxplot(x[column])
            plt.xlabel(column,fontsize=20)
       
    plotnumber +=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# As there are very less outlier so we will ignore outlier we will not delete any data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#now we will input our model to get good accuracy

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score

lr=LinearRegression()
model=lr.fit(x_train,y_train)
y_pred=model.predict(x_test)
rmse=mean_squared_error(y_test, y_pred)**0.5
print("rmse=",rmse)
r2=r2_score(y_test, y_pred)
print("r2=",r2)
score=cross_val_score(model,x,y,cv=5,scoring="r2")
print("cv_score=",score)
# Out:
# rmse= 7.0049387062200115
# r2= 0.45411310692077433
# cv_score= [ 0.71136471 -2.21099237  0.38808753  0.73556937  0.5797478 ]

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
svr=SVR()
model=svr.fit(x_train,y_train)
y_pred=model.predict(x_test)
rmse=mean_squared_error(y_test, y_pred)**0.5
print("rmse=",rmse)
r2=r2_score(y_test, y_pred)
print("r2=",r2)
score=cross_val_score(model,x,y,cv=5,scoring="r2")
print("cv_score=",score)
# Out:
# rmse= 9.98264887629953
# r2= -0.10862732668400299
# cv_score= [-0.15989899 -0.7621832  -0.31850161 -0.75169003 -0.29872051]

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
neigh = KNeighborsRegressor(n_neighbors=5)
model = neigh.fit(x_train,y_train)
y_pred=model.predict(x_test)
rmse=mean_squared_error(y_test, y_pred)**0.5
print("rmse=",rmse)
r2=r2_score(y_test, y_pred)
print("r2=",r2)
score=cross_val_score(model,x,y,cv=5,scoring="r2")
print("cv_score=",score)
# Out:
# rmse= 9.069729874698584
# r2= 0.08487021013597051
# cv_score= [-0.52888099 -3.77251908  0.16639756  0.08754788  0.51055621]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
rf=RandomForestRegressor(max_depth=2, random_state=0)
model=rf.fit(x_train,y_train)
y_pred=model.predict(x_test)
rmse=mean_squared_error(y_test, y_pred)**0.5
print("rmse=",rmse)
r2=r2_score(y_test, y_pred)
print("r2=",r2)
score=cross_val_score(model,x,y,cv=5,scoring="r2")
print("cv_score=",score)
# Out:
# rmse= 6.67710559833357
# r2= 0.5040127904305592
# cv_score= [ 0.14514291 -4.78529284  0.07812369  0.27048261  0.67616428]

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
gbr = GradientBoostingRegressor(random_state=0)
model=gbr.fit(x_train,y_train)
y_pred=model.predict(x_test)
rmse=mean_squared_error(y_test, y_pred)**0.5
print("rmse=",rmse)
r2=r2_score(y_test, y_pred)
print("r2=",r2)
score=cross_val_score(model,x,y,cv=5,scoring="r2")
print("cv_score=",score)
# Out:
# rmse= 5.857011785515095
# r2= 0.6183667694672874
# cv_score= [-0.20453509 -6.5747648   0.23660684  0.40973683  0.52645838]

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
abr = AdaBoostRegressor(random_state=0)
model=abr.fit(x_train,y_train)
y_pred=model.predict(x_test)
rmse=mean_squared_error(y_test, y_pred)**0.5
print("rmse=",rmse)
r2=r2_score(y_test, y_pred)
print("r2=",r2)
score=cross_val_score(model,x,y,cv=5,scoring="r2")
print("cv_score=",score)
# Out:
# rmse= 6.694471936366805
# r2= 0.50142943070306
# cv_score= [ 0.28814369 -4.87054707  0.26056929  0.3334478   0.83258136]

# %%
# as we can see GradientBoostingRegressor has highest so we will confirm that model

# %%
#Saving the model in pkl file
import joblib
joblib.dump(ab,"Baseball_Pred.pkl")

model = joblib.load("Baseball_Pred.pkl")

#Predicting the saved model
prediction = model.predict(x_test)

#Converting the result into DataFrame
prediction = pd.DataFrame(prediction)

#Saving the result into CSV
prediction.to_csv("Results_base.csv",index=False)
